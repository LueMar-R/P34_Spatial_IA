# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
T = list(range(1, 500))

# %%
T0 = 1
tau = 1000

for t in T :
 print(T0*np.exp(-t/tau))
# Out:
# 0.999000499833375
# 0.9980019986673331
# 0.997004495503373
# 0.9960079893439915
# 0.9950124791926823
# 0.9940179640539353
# 0.9930244429332351
# 0.9920319148370607
# 0.9910403787728836
# 0.9900498337491681
# 0.9890602787753687
# 0.9880717128619305
# 0.9870841350202876
# 0.9860975442628619
# 0.9851119396030626
# 0.9841273200552851
# 0.9831436846349096
# 0.9821610323583008
# 0.981179362242806
# 0.9801986733067553
# 0.9792189645694596
# 0.97824023505121
# 0.9772624837732771
# 0.9762857097579093
# 0.9753099120283326
# 0.9743350896087494
# 0.9733612415243368
# 0.9723883668012469
# 0.9714164644666048
# 0.9704455335485082
# 0.9694755730760259
# 0.9685065820791976
# 0.967538559589032
# 0.9665715046375066
# 0.9656054162575665
# 0.9646402934831231
# 0.9636761353490535
# 0.9627129408911995
# 0.9617507091463667
# 0.9607894391523232
# 0.9598291299477989
# 0.9588697805724845
# 0.9579113900670306
# 0.9569539574730467
# 0.9559974818331
# 0.9550419621907147
# 0.9540873975903711
# 0.9531337870775047
# ...

# %%
print(y)
# Out:
# 0.9990014973385309

# %%
a = np.random.uniform()
print(a)
# Out:
# 0.2442171023656483

# %%
print(a)
# Out:
# 0.7016501742084531

# %%
np.exp(-0.3/0.8)
# Out:
# 0.6872892787909722

# %%
np.exp(-0.6*0.8)
# Out:
# 0.6187833918061408

# %%
np.exp(-0.6*0.6)
# Out:
# 0.697676326071031

# %%
np.exp(-0.6*0.4)
# Out:
# 0.7866278610665535

# %%
np.exp(-0.6*0.2)
# Out:
# 0.8869204367171575

# %%
np.exp(-0.6*0.09)
# Out:
# 0.9474321065017983

# %%
a = 1
b = 2
c = 3

# %%
d = b = 8

# %%
d
# Out:
# 8

# %%
b
# Out:
# 8
